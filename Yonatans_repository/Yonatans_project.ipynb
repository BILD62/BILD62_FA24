# %% [markdown]
# #### Main Jupyter notebook of Yonatan's project

# %%
import Yonatans_functions as yf
import matplotlib.pyplot as plt
import numpy as np

# %%
x = np.linspace(0,10,100)
fig, ax = plt.subplots(1,2,figsize=(10,4),sharex=True,sharey=True)
ax[0].plot(x,yf.fun1(x),'-r')
ax[1].plot(x,yf.fun2(x),'-r')

ax[0].set_xlabel('x')
ax[1].set_xlabel('x')
ax[0].set_ylabel('fun1(x)')
ax[1].set_ylabel('fun2(x)')

plt.show()
